# %%
import pandas as pd

# %%
df = pd.read_csv('data/villages.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83763 entries, 0 to 83762
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postal_code    83763 non-null  int64
#  1   village        83763 non-null  object
#  2   Kode Wilayah   83763 non-null  int64
#  3   Unnamed: 3     83763 non-null  int64
#  4   Unnamed: 4     83763 non-null  int64
#  5   Unnamed: 5     83763 non-null  int64
#  6   code           83763 non-null  int64
#  7   district_code  83763 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 5.1+ MB
# None
